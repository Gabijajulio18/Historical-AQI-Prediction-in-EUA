# %%
import pandas as pd

# %%
# Load the cleaned dataset (after filling missing AQI values)
cleaned_path = "../data/processed/cleaned_pollutants_sorted.csv"
df = pd.read_csv(cleaned_path)

# Convert 'Date Local' to datetime if needed
df['Date Local'] = pd.to_datetime(df['Date Local'], errors='coerce')

# Summary of missing values for AQI columns
missing_so2_aqi = df['SO2 AQI'].isnull().sum()
missing_co_aqi = df['CO AQI'].isnull().sum()

print(f"Missing SO2 AQI values after estimation: {missing_so2_aqi}")
print(f"Missing CO AQI values after estimation: {missing_co_aqi}")

# Show some rows with missing SO2 or CO AQI (should be very few or none)
print("\nRows with missing SO2 AQI:")
print(df[df['SO2 AQI'].isnull()].head())

print("\nRows with missing CO AQI:")
print(df[df['CO AQI'].isnull()].head())

# Optional: Verify that the estimated AQI values correspond to the compute_aqi function logic
# For example, show rows where original AQI was missing but Mean values exist
print("\nSample rows where SO2 AQI was estimated:")
print(df[(df['SO2 AQI'].notnull()) & (df['SO2 Mean'].notnull())].sample(5))

print("\nSample rows where CO AQI was estimated:")
print(df[(df['CO AQI'].notnull()) & (df['CO Mean'].notnull())].sample(5))

# Quick statistics summary for SO2 and CO AQI columns
print("\nSO2 AQI stats:")
print(df['SO2 AQI'].describe())

print("\nCO AQI stats:")
print(df['CO AQI'].describe())
# Out:
# Missing SO2 AQI values after estimation: 0
# Missing CO AQI values after estimation: 0
#
# Rows with missing SO2 AQI:
# Empty DataFrame
# Columns: [Unnamed: 0, State Code, County Code, Site Num, Address, State, County, City, Date Local, NO2 Units, NO2 Mean, NO2 1st Max Value, NO2 1st Max Hour, NO2 AQI, O3 Units, O3 Mean, O3 1st Max Value, O3 1st Max Hour, O3 AQI, SO2 Units, SO2 Mean, SO2 1st Max Value, SO2 1st Max Hour, SO2 AQI, CO Units, CO Mean, CO 1st Max Value, CO 1st Max Hour, CO AQI, SO2_AQI_missing, CO_AQI_missing]
# Index: []
#
# [0 rows x 31 columns]
#
# Rows with missing CO AQI:
# Empty DataFrame
# Columns: [Unnamed: 0, State Code, County Code, Site Num, Address, State, County, City, Date Local, NO2 Units, NO2 Mean, NO2 1st Max Value, NO2 1st Max Hour, NO2 AQI, O3 Units, O3 Mean, O3 1st Max Value, O3 1st Max Hour, O3 AQI, SO2 Units, SO2 Mean, SO2 1st Max Value, SO2 1st Max Hour, SO2 AQI, CO Units, CO Mean, CO 1st Max Value, CO 1st Max Hour, CO AQI, SO2_AQI_missing, CO_AQI_missing]
# Index: []
#
# [0 rows x 31 columns]
#
# Sample rows where SO2 AQI was estimated:
#          Unnamed: 0  State Code  County Code  Site Num  \
# 1014916       61529          23            3      1100
# 1653172      111369          48          113        69
# 598220        23646           6           37      1103
# 348370         8420           6           13      1002
# 1583516       77099          48          113        69
#
#                                          Address       State        County  \
# 1014916  8 NORTHERN ROAD, PRESQUE ISLE, ME 04769       Maine     Aroostook
# 1653172                       1415 Hinton Street       Texas        Dallas
# 598220               1630 N MAIN ST, LOS ANGELES  California   Los Angeles
# 348370                     5551 BETHEL ISLAND RD  California  Contra Costa
# 1583516                       1415 Hinton Street       Texas        Dallas
#
#                   City Date Local          NO2 Units  ...  SO2 1st Max Value  \
# 1014916   Presque Isle 2010-06-29  Parts per billion  ...                0.0
# 1653172         Dallas 2012-10-25  Parts per billion  ...                0.1
# 598220     Los Angeles 2013-07-28  Parts per billion  ...               -0.1
# 348370   Bethel Island 2006-08-20  Parts per billion  ...                5.3
# 1583516         Dallas 2004-05-07  Parts per billion  ...                1.0
#
#          SO2 1st Max Hour  SO2 AQI           CO Units   CO Mean  \
# 1014916                 2  0.00000  Parts per million  0.200000
# 1653172                 1  0.00000  Parts per million  0.120833
# 598220                 14  4.90086  Parts per million  0.300000
# 348370                 17  5.00000  Parts per million  0.326087
# 1583516                 8  1.00000  Parts per million  0.400000
#
#          CO 1st Max Value  CO 1st Max Hour  CO AQI  SO2_AQI_missing  \
# 1014916               0.2                0     2.0                0
# 1653172               0.2               16     2.0                0
# 598220                0.3                0     3.0                1
# 348370                0.4                0     4.0                0
# 1583516               0.5                0     6.0                0
#
#         CO_AQI_missing
# 1014916              0
# 1653172              0
# 598220               0
# 348370               0
# 1583516              0
#
# [5 rows x 31 columns]
#
# Sample rows where CO AQI was estimated:
#          Unnamed: 0  State Code  County Code  Site Num  \
# 811433        54006          12           95      2002
# 1524649      111819          42          133         8
# 233241        13368           6           37      1002
# 763724        53862          10            3      2004
# 47000           730           4           13      3002
#
#                                          Address         State       County  \
# 811433                              MORRIS BLVD.       Florida       Orange
# 1524649                                 HILL ST.  Pennsylvania         York
# 233241                 228 W. PALM AVE., BURBANK    California  Los Angeles
# 763724                 MLK BLVD AND JUSTISON ST.      Delaware   New Castle
# 47000    1645 E ROOSEVELT ST-CENTRAL PHOENIX STN       Arizona     Maricopa
#
#                 City Date Local          NO2 Units  ...  SO2 1st Max Value  \
# 811433   Winter Park 2012-11-06  Parts per billion  ...                1.0
# 1524649         York 2014-06-09  Parts per billion  ...                1.3
# 233241       Burbank 2003-04-21  Parts per billion  ...                0.0
# 763724    Wilmington 2014-05-31  Parts per billion  ...                2.3
# 47000        Phoenix 2009-07-02  Parts per billion  ...                1.0
#
#          SO2 1st Max Hour  SO2 AQI           CO Units   CO Mean  \
# 811433                 20      1.0  Parts per million  0.286957
# 1524649                 8      1.0  Parts per million  0.209091
# 233241                  2      0.0  Parts per million  0.313043
# 763724                  3      3.0  Parts per million  0.120833
# 47000                  23      0.0  Parts per million  0.379167
#
#          CO 1st Max Value  CO 1st Max Hour  CO AQI  SO2_AQI_missing  \
# 811433                0.5                7     3.0                0
# 1524649               0.4               15     2.0                0
# 233241                0.5                5     4.0                0
# 763724                0.2                0     2.0                0
# 47000                 0.6               23     4.0                0
#
#         CO_AQI_missing
# 811433               0
# 1524649              0
# 233241               0
# 763724               0
# 47000                0
#
# [5 rows x 31 columns]
#
# SO2 AQI stats:
# count    1.746661e+06
# mean     4.900860e+00
# std      9.143709e+00
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      2.000000e+00
# 75%      6.000000e+00
# max      2.000000e+02
# Name: SO2 AQI, dtype: float64
#
# CO AQI stats:
# count    1.746661e+06
# mean     5.077937e+00
# std      4.922263e+00
# min      0.000000e+00
# 25%      2.000000e+00
# 50%      4.000000e+00
# 75%      6.000000e+00
# max      2.010000e+02
# Name: CO AQI, dtype: float64

# %%
# Check how many values were imputed
so2_imputed = df["SO2_AQI_missing"].sum()
co_imputed = df["CO_AQI_missing"].sum()

print(f"SO2 AQI values imputed: {so2_imputed}")
print(f"CO AQI values imputed: {co_imputed}")
# Out:
# SO2 AQI values imputed: 10756
# CO AQI values imputed: 590

# %%
# Display some imputed rows
df_imputed = df[(df["SO2_AQI_missing"] == 1) | (df["CO_AQI_missing"] == 1)]
df_imputed[["Date Local", "State", "City", "SO2 Mean", "SO2 AQI", "SO2_AQI_missing", "CO Mean",
             "CO AQI", "CO_AQI_missing"]].head(10)
# Out:
#     Date Local    State        City  SO2 Mean  SO2 AQI  SO2_AQI_missing  \
# 18  2013-12-05  Alabama  Birmingham   1.89779  4.90086                1
# 19  2013-12-05  Alabama  Birmingham   1.89779  4.90086                1
# 22  2013-12-06  Alabama  Birmingham   1.89779  4.90086                1
# 23  2013-12-06  Alabama  Birmingham   1.89779  4.90086                1
# 34  2013-12-09  Alabama  Birmingham   1.89779  4.90086                1
# 35  2013-12-09  Alabama  Birmingham   1.89779  4.90086                1
# 90  2013-12-23  Alabama  Birmingham   1.89779  4.90086                1
# 91  2013-12-23  Alabama  Birmingham   1.89779  4.90086                1
# 218 2014-03-09  Alabama  Birmingham   1.89779  4.90086                1
# 219 2014-03-09  Alabama  Birmingham   1.89779  4.90086                1
#
#       CO Mean  CO AQI  CO_AQI_missing
# 18   0.126818     1.0               0
# 19   0.108333     2.0               0
# 22   0.139545     2.0               0
# 23   0.141667     2.0               0
# 34   0.128500     1.0               0
# 35   0.127778     3.0               0
# 90   0.058500     1.0               0
# 91   0.088889     2.0               0
# 218  0.264545     3.0               0
# 219  0.329167     8.0               0

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming df is your DataFrame with the imputed data and the missing flags

def plot_original_vs_imputed(df, column, missing_flag_col):
    plt.figure(figsize=(10, 6))
    sns.kdeplot(df.loc[df[missing_flag_col] == 0, column].dropna(), label="Original Values")
    sns.kdeplot(df.loc[df[missing_flag_col] == 1, column].dropna(), label="Imputed Values")
    plt.title(f"Distribution of Original vs Imputed values for {column}")
    plt.xlabel(column)
    plt.ylabel("Density")
    plt.legend()
    plt.show()

# Plot for SO2 Mean
plot_original_vs_imputed(df, "SO2 Mean", "SO2_AQI_missing")

# Plot for SO2 AQI
plot_original_vs_imputed(df, "SO2 AQI", "SO2_AQI_missing")
# Out:
# /tmp/ipykernel_9860/3355323046.py:9: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(df.loc[df[missing_flag_col] == 1, column].dropna(), label="Imputed Values")
